# %%
import pandas as pd
import numpy as np

# mannual fixed internship status & align names in excel with bc concat was being weird

# %%
f17_s18 = pd.read_excel("internship_survey_fa17_sp18.xlsx")
f17_s18["Internship Year"] = "2017-2018"

f18_s19 = pd.read_excel("internship_survey_fa18_sp19.xlsx")
f18_s19["Internship Year"] = "2018-2019"

f19_s20 = pd.read_excel("internship_survey_fa19_sp20.xlsx")
f19_s20["Internship Year"] = "2019-2020"

f20_s21 = pd.read_excel("internship_survey_fa20_sp21.xlsx")
f20_s21["Internship Year"] = "2020-2021"

f21_f23 = pd.read_excel("internship_survey_fa21_fa23.xlsx")
f21_f23["Recorded Date"] = f21_f23["Recorded Date"].astype(str)
f21_f23["Internship Year"] = f21_f23["Recorded Date"].apply(lambda x: "2021-2022" if ( (int(x.split("-")[1])>=9 and int(x.split("-")[0][2:4])==21) or ( int(x.split("-")[1])<9 and int(x.split("-")[0][2:4])==22 )) \
                                       else ("2022-2023"  if ( (int(x.split("-")[1])>=9 and int(x.split("-")[0][2:4])==22) or ( int(x.split("-")[1])<9 and int(x.split("-")[0][2:4])==23 )) \
                                           else ("2023-2024"  if ( (int(x.split("-")[1])>=9 and int(x.split("-")[0][2:4])==23) or ( int(x.split("-")[1])<9 and int(x.split("-")[0][2:4])==24 )) \
                                             else "CHECK" )) )
f21_f23["What summer/year internship are you reporting?"] = f21_f23["What summer/year internship are you reporting?"].apply(lambda x: "Summer 2022" if x == 9 else x)
f21_f23["Recorded Date"] = pd.to_datetime(f21_f23["Recorded Date"])

f17_f23 =  pd.concat([f17_s18, f18_s19, f19_s20, f20_s21, f21_f23])
f17_f23.sort_index(axis = 1, inplace = True)

# %%
#Don't need
f17_f23.drop(["Business Major(s) / Certificate(s) - Accounting",  "Business Major(s) / Certificate(s) - Actuarial Science", "Business Major(s) / Certificate(s) - Certificate in Business", "Business Major(s) / Certificate(s) - Certificate in Entrepreneurship", \
 "Business Major(s) / Certificate(s) - Finance, Investment & Banking", "Business Major(s) / Certificate(s) - Information Systems",  "Business Major(s) / Certificate(s) - International Business", "Business Major(s) / Certificate(s) - Management & Human Resources", \
 "Business Major(s) / Certificate(s) - Marketing", "Business Major(s) / Certificate(s) - Master of Accountancy (IMAcc/GMAcc)", "Business Major(s) / Certificate(s) - Operations and Technology Management", "Business Major(s) / Certificate(s) - Real Estate and Urban Land Economics", \
 "Business Major(s) / Certificate(s) - Risk Management and Insurance", "Business Major(s) / Certificate(s) - Supply Chain Management", "Business Major(s) / Certificate(s) - Supply Chain Management Specialization", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Other - Text", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Other", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Other - Text", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Other", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Other - Text", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Other", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Other", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Other - Text", \
 "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Other", \
 "Employer Industry: What type of work/service does the company as a whole provide to consumers? - Other: - Text", "How did you find out about this opportunity? - Other - Text", "How did you find out about this opportunity? - Other - Text.1", \
 "How did you find out about this opportunity? - Selected Choice - Other", "How did you find out about this opportunity? - Selected Choice - Other.1", "If not seeking an internship or part-time role, why not? - Other - Text", "If not seeking an internship or part-time role, why not? - Selected Choice - Other", \
 "If you chose \"Other:\" for Employer Industry, please describe here:", "If you chose \"Other:\" for Job Function/Career Pathway, please describe here:", "What additional major are you pursuing outside of the Wisconsin School of Business?", \
 "What additional major(s) are you pursuing outside of the Wisconsin School of Business?", "Why didn't you participate in an off-campus, employer-hosted career experience this year? - Other - Text", \
 "Why didn't you participate in an off-campus, employer-hosted career experience this year? Events may have been either in-person or a virtual \"visit.\" - Other - Text","Are you pursuing an additional major outside of the WSB?", \
 "Job Function/Career Pathway: What work do you perform in this particular role? - Other - Text", "Thank you"], axis=1, inplace=True)

# %%
#Mergings
f17_f23['How did you find out about this opportunity? - Selected Choice - Through on-campus resources (BBA Staff, faculty, career fair, Handshake, etc.)'] = pd.concat([f17_f23['How did you find out about this opportunity? - Selected Choice - Through on-campus resources (BBA Staff, faculty, career fair, Handshake, etc.)'], \
                                                                                                      f17_f23['How did you find out about this opportunity? - Selected Choice - Through on-campus resources (BBA Staff, faculty, career fair, Buckynet, etc.)'], \
                                                                                                              f17_f23["How did you find out about this opportunity? - Selected Choice - Through UW career services resources (BBA Staff, career fair, Handshake, etc.)"]], axis=0, ignore_index=True)

f17_f23['How did you find out about this opportunity? - Selected Choice - Referral from friends or family members'] = pd.concat([f17_f23['How did you find out about this opportunity? - Selected Choice - Referral from friends or family members'], \
                                                                                                      f17_f23['How did you find out about this opportunity? - Selected Choice - Referral from a family member or friend (parent of friend)']], axis=0, ignore_index=True)

f17_f23['Enter the date you accepted this offer (ex: MM/DD/YYYY) if applicable.'] = pd.concat([f17_f23["Enter the date you accepted this offer (ex: 10/4/2017) if applicable."],f17_f23['Enter the date you accepted this offer (ex: MM/DD/YYYY) if applicable.'], f17_f23["Enter the date you accepted this offer (ex: MM/DD/YYYY), if applicable."] ], axis=0, ignore_index=True)

f17_f23['Enter the date you received this offer (ex: MM/DD/YYYY).'] = pd.concat([f17_f23['Enter the date you received this offer (ex: 10/4/2017).'],f17_f23[ 'Enter the date you received this offer (ex: MM/DD/YYYY).']], axis=0, ignore_index=True)

f17_f23["Why didn't you participate in an off-campus, employer-hosted career experience this year? - Selected Choice"] = pd.concat([f17_f23["Why didn't you participate in an off-campus, employer-hosted career experience this year? - Selected Choice"],f17_f23["Why didn't you participate in an off-campus, employer-hosted career experience this year? Events may have been either in-person or a virtual \"visit.\" - Selected Choice"]], axis=0, ignore_index=True)

f17_f23['Anticipated Graduation Date:'] = pd.concat([f17_f23['Anticipated Graduation Date:'], f17_f23['Anticipated Graduation Date: (If you are planning on attending a graduate school program, like the IMAcc or MS in Real Estate, please indicate your planned graduation from the Bachelor of Business Administration Program.)']], axis=0, ignore_index=True)

f17_f23["Employer Industry: What type of work/service does the company as a whole provide to consumers?"] = pd.concat([f17_f23['Employer Industry: What does your employer offer to clients?'], f17_f23["Employer Industry: What type of work/service does the company as a whole provide to consumers?"], \
                                                                                                      f17_f23["Employer Industry: What type of work/service does the company as a whole provide to consumers? - Selected Choice"]], axis=0, ignore_index=True)

f17_f23['Monthly Salary (Calculate: hourly rate x hours worked per week x 52 weeks; divide by 12)'] = pd.concat([f17_f23['Monthly Salary (Calculate: hourly rate x hours worked per week x 52 weeks; divide by 12)'], \
                                                                                                      f17_f23['Monthly Salary in US Dollars (Calculate: hourly rate x hours worked per week x 52 weeks; divide by 12). If paid in another currency, please convert to USD.']], axis=0, ignore_index=True)

f17_f23['Job Function: What work do you perform in your role? - Other - Text'] = pd.concat([f17_f23['Job Function: What work do you perform in your role? - Other - Text'], \
                                                                                                      f17_f23['Job Function: What work do you perform in this particular role? - Other - Text']], axis=0, ignore_index=True)

f17_f23['Job Function: What work do you perform in your role? - Selected Choice'] = pd.concat([f17_f23['Job Function: What work do you perform in your role? - Selected Choice'], f17_f23["Job Function/Career Pathway: What work do you perform in this particular role? - Selected Choice"],\
                                                                                                      f17_f23['Job Function: What work do you perform in this particular role? - Selected Choice']], axis=0, ignore_index=True)

f17_f23["internship career alignment"] = f17_f23["internship career alignment"].apply(lambda x: 4 if x=="Yes" else ( 2 if x== "No" else x))

f17_f23["If not seeking an internship or part-time role, why not? - Selected Choice - I didn't find any opportunities of interest via BBA Career Services"] = pd.concat([f17_f23["If not seeking an internship or part-time role, why not? - Selected Choice - I didn't find any opportunities of interest via BBA Career Services"], \
                                                                                                      f17_f23["If not seeking an internship or part-time role, why not? - Selected Choice - I didn't find any opportunities of interest via the BBA Career Engagement Team"]], axis=0, ignore_index=True)

f17_f23["How did you find out about this opportunity? - Selected Choice - Through the UW community (faculty, alumni, student organizations, etc.)"] = pd.concat([f17_f23["How did you find out about this opportunity? - Selected Choice - Through the UW community (faculty, alumni, etc.)"], \
                                                                                                      f17_f23["How did you find out about this opportunity? - Selected Choice - Through the UW community (faculty, alumni, student organizations, etc.)"]], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Employer site visit (individually or with my student organization)'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Employer site visit (individually or with my student organization)'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Employer site visit (individually or with my student organization)"],\
                                                                                               f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Employer site visit (individually or with my student organization)'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Employer site visit (individually or with my student organization)"]], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I did not participate in any off-campus employer-hosted events this year'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - I did not participate in any off-campus employer-hosted events this year'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - I did not participate in any off-campus employer-hosted events this year"],\
                                                                                               f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I did not participate in any off-campus employer-hosted events this year'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I did not participate in any off-campus employer-hosted events this year"]], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Job shadow experience'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Job shadow experience'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Job shadow experience"],\
                                                                                               f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Job shadow experience'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Job shadow experience"]], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Leadership development experience'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Leadership development experience'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Leadership development experience"],\
                                                                                               f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Leadership development experience'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Leadership development experience"]], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Networking event or roundtable'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Networking event or roundtable'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Networking event or roundtable"],\
                                                                                               f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Networking event or roundtable'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Networking event or roundtable"]], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Participation in a case competition'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Participation in a case competition'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Participation in a case competition"],\
                                                                                               f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Participation in a case competition'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Participation in a case competition"]], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Volunteering or service opportunity (individually or with my student organization)'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Volunteering or service opportunity (individually or with my student organization)'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Volunteering or service opportunity (individually or with my student organization)"],\
                                                                                               f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Volunteering or service opportunity (individually or with my student organization)']], axis=0, ignore_index=True)

f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I participated in some form of event in-person'] = pd.concat([f17_f23['Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I participated in some form of event in-person'], \
                                                                                               f17_f23["Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I participated in some form of event in-person"]], axis=0, ignore_index=True)


#Drop columns that were merged
f17_f23.drop(['How did you find out about this opportunity? - Selected Choice - Referral from a family member or friend (parent of friend)', "Enter the date you accepted this offer (ex: 10/4/2017) if applicable.", \
             'Enter the date you received this offer (ex: 10/4/2017).', "How did you find out about this opportunity? - Selected Choice - Through UW career services resources (BBA Staff, career fair, Handshake, etc.)", \
             "Enter the date you accepted this offer (ex: MM/DD/YYYY), if applicable.", "How did you find out about this opportunity? - Selected Choice - Through on-campus resources (BBA Staff, faculty, career fair, Buckynet, etc.)", \
             "Why didn't you participate in an off-campus, employer-hosted career experience this year? Events may have been either in-person or a virtual \"visit.\" - Selected Choice", \
             'Anticipated Graduation Date: (If you are planning on attending a graduate school program, like the IMAcc or MS in Real Estate, please indicate your planned graduation from the Bachelor of Business Administration Program.)', \
             "Employer Industry: What type of work/service does the company as a whole provide to consumers? - Selected Choice", 'Employer Industry: What does your employer offer to clients?', \
             "Monthly Salary in US Dollars (Calculate: hourly rate x hours worked per week x 52 weeks; divide by 12). If paid in another currency, please convert to USD.", "Job Function: What work do you perform in this particular role? - Other - Text", \
             "Job Function: What work do you perform in this particular role? - Selected Choice", "Job Function/Career Pathway: What work do you perform in this particular role? - Selected Choice", \
             "If not seeking an internship or part-time role, why not? - Selected Choice - I didn't find any opportunities of interest via the BBA Career Engagement Team", "How did you find out about this opportunity? - Selected Choice - Through the UW community (faculty, alumni, etc.)", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Employer site visit (individually or with my student organization)", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Employer site visit (individually or with my student organization)", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Employer site visit (individually or with my student organization)", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - I did not participate in any off-campus employer-hosted events this year", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - I did not participate in any off-campus employer-hosted events this year", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I did not participate in any off-campus employer-hosted events this year", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Job shadow experience", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Job shadow experience", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Job shadow experience", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Leadership development experience", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Leadership development experience", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Leadership development experience", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Networking event or roundtable", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Networking event or roundtable", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Networking event or roundtable", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2018 or Spring semester of 2019? (please select all that apply) - Selected Choice - Participation in a case competition", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Participation in a case competition", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Participation in a case competition", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - Volunteering or service opportunity (individually or with my student organization)", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2019 or Spring semester of 2020? (please select all that apply) - Selected Choice - Volunteering or service opportunity (individually or with my student organization)", \
             "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the Fall semester of 2020 or Spring semester of 2021? (Please select all that apply: unless otherwise noted, assume all events are virtual) - Selected Choice - I participated in some form of event in-person"], axis=1, inplace=True)


#Shortening names
campevents = [col for col in f17_f23.columns if "Did you participate in any off-campus career-related events, experiences or workshops hosted by employers or industry organizations in the academic year preceding your internship?" in col]
for coll in campevents:
    f17_f23.rename(columns = {coll: "Off campus opportunities" + coll.split("Selected Choice")[1]} , inplace = True) 
    
campopp = [col for col in f17_f23.columns if "How did you find out about this opportunity? - Selected Choice" in col]
for coll in campopp:
    f17_f23.rename(columns = {coll: "Opportunity exposure" + coll.split("Selected Choice")[1]} , inplace = True) 
    
notseek = [col for col in f17_f23.columns if "If not seeking an internship or part-time role, why not? - Selected Choice" in col]
for coll in notseek:
    f17_f23.rename(columns = {coll: "Why not seeking" + coll.split("Selected Choice")[1]} , inplace = True) 
    
compen = [col for col in f17_f23.columns if "What compensation, if any, are you receiving for this internship? " in col]
for coll in compen:
    f17_f23.rename(columns = {coll: "Compensation type" + coll.split("internship?")[1]} , inplace = True) 

f17_f23.rename(columns={'Will you be working primarily in-person or remotely? "In-person" can refer to working either at your employer\'s office or at a client\'s location, if your position would work on-site with a client.': "Primarily in-person or remote?", \
                       "If you are seeking an internship, please comment on your career goals and what steps you are taking towards achieving these goals." : "Steps taken/career goals in seeking an internship"}, inplace=True)

f17_f23.columns
# Out:
# Index(['Anticipated Graduation Date:', 'City:', 'Country (ex: USA)',
#        'Off campus opportunities - Employer site visit (individually or with my student organization)',
#        'Off campus opportunities - I did not participate in any off-campus employer-hosted events this year',
#        'Off campus opportunities - I participated in some form of event in-person',
#        'Off campus opportunities - Job shadow experience',
#        'Off campus opportunities - Leadership development experience',
#        'Off campus opportunities - Networking event or roundtable',
#        'Off campus opportunities - Participation in a case competition',
#        'Off campus opportunities - Volunteering or service opportunity (individually or with my student organization)',
#        'Distribution Channel', 'Duration (in seconds)',
#        'Employer Industry: What type of work/service does the company as a whole provide to consumers?',
#        'Employer's Name:', 'End Date',
# ...

# %%
f17_f23.to_excel("clean_f17_f23.xlsx", "clean_f17_f23.xlsx")
